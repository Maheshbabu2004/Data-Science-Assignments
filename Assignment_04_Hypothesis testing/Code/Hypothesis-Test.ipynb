# %%
import pandas as pd
import numpy as np
from scipy.stats import t

# %%
#given data from the question
sample_mean=3050
theoritical_mean=1000+5*600
standard_deviation=5*25
sample_size=25
alpha=0.05

# %%
#calculating t_statistics
standard_error=standard_deviation/np.sqrt(sample_size)
t_statistics=(sample_mean-theoritical_mean)/standard_error

# %%
print("standard_error :",standard_error)
print("t_statistics:",t_statistics)
# Out:
# standard_error : 25.0
# t_statistics: -38.0

# %%
dof=sample_mean-1      #degree of freedom
dof
# Out:
# 3049

# %%
#determining the critical value
critical_value=t.ppf(1-alpha,dof)
critical_value
# Out:
# np.float64(1.6453535400529384)

# %%
#Decision making
if t_statistics<critical_value:
    print("Accept H0:The operating cost for a franchise in a week is not changed and retained same as $1000+$5X for X=600")
else:
    print("Reject H0:The operating cost for a franchise in a week is changed as greater than $1000+$5X for X=600")
# Out:
# Accept H0:The operating cost for a franchise in a week is not changed and retained same as $1000+$5X for X=600

# %%
#conclusion:
#..........Based on the decision in step 4, we con concluded that there is no strong evidence to support the restaurant owners' claim that the weekly operating costs are higher than the model suggests
