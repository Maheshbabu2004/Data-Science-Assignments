# %%
#Exercise 1: Prime Number
#Write a python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# Functions to check if a number is prime
def is_prime(number):
    if number <= 1:
        return False   
    for i in range(2, number):
        if number % i == 0:
            return False   
    return True 
num = int(input("Enter a number: "))
if is_prime(num):
    print(f"{num} is a prime Number:")
else:
    print(f"{num} is not a prime Number:")
# Out:
# Enter a number:  19
# 19 is a prime Number:

# %%
#Exrcise 2: product of Random Numbers
#Develop a python program that generate two random numbers and ask the user to enter the product of these numbers. The Program should then check if the user's answer is correct and display an appropriate message.

import random
num1 = random.randint(1,10)
num2 = random.randint(1,10)
print(f"What is the product of {num1} and {num2}?")
user_answer = int(input("your answer: "))
correct_answer = num1 * num2
if user_answer == correct_answer:
    print("You are correct")
else:
    print("You are wrong the correct answer is:",correct_answer)
# Out:
# What is the product of 7 and 5?
# your answer:  35
# You are correct

# %%
#Exercise 3: square of Even/odd Numbers
#Create a python script that prints the squares of all even or odd numbers within range of 100 to 200. choose either even or odd numbers and document you choice in the code.

for num in range(100,201):
    if num%2 != 0:
        print(f"{num}^2 = {num**2}")
# Out:
# 101^2 = 10201
# 103^2 = 10609
# 105^2 = 11025
# 107^2 = 11449
# 109^2 = 11881
# 111^2 = 12321
# 113^2 = 12769
# 115^2 = 13225
# 117^2 = 13689
# 119^2 = 14161
# 121^2 = 14641
# 123^2 = 15129
# 125^2 = 15625
# 127^2 = 16129
# 129^2 = 16641
# 131^2 = 17161
# 133^2 = 17689
# 135^2 = 18225
# 137^2 = 18769
# 139^2 = 19321
# 141^2 = 19881
# 143^2 = 20449
# 145^2 = 21025
# 147^2 = 21609
# 149^2 = 22201
# 151^2 = 22801
# 153^2 = 23409
# 155^2 = 24025
# 157^2 = 24649
# 159^2 = 25281
# 161^2 = 25921
# 163^2 = 26569
# 165^2 = 27225
# 167^2 = 27889
# 169^2 = 28561
# 171^2 = 29241
# 173^2 = 29929
# 175^2 = 30625
# 177^2 = 31329
# 179^2 = 32041
# 181^2 = 32761
# 183^2 = 33489
# 185^2 = 34225
# 187^2 = 34969
# 189^2 = 35721
# 191^2 = 36481
# 193^2 = 37249
# 195^2 = 38025
# 197^2 = 38809
# 199^2 = 39601

# %%
#Exercise 4: Word counter
def word_counter(input_text):
    words = input_text.split()
    word_count = {}
    for word in words:
        word = word.strip('.,!?:;"\'').lower()   #removing the punctuations from the word
        word_count[word] = word_count.get(word, 0) + 1
    for word, count in word_count.items():
        print(f"'{word}': {count}")
# Example usage
input_text = "This is a sample text. This text will be used to demonstrate the word counter."
word_counter(input_text)
# Out:
# 'this': 2
# 'is': 1
# 'a': 1
# 'sample': 1
# 'text': 2
# 'will': 1
# 'be': 1
# 'used': 1
# 'to': 1
# 'demonstrate': 1
# 'the': 1
# 'word': 1
# 'counter': 1

# %%
#Exercise 5: check for palindrome
def is_palindrome(text):
    cleaned_text = text.lower().replace(" "," ")
    return cleaned_text == cleaned_text[::-1]
user_input = input("Enter a word, phrase, or number:")
if is_palindrome(user_input):
    print("It is a palindrome")
else:
    print("It is not a palindrome")
# Out:
# Enter a word, phrase, or number: deified
# It is a palindrome
