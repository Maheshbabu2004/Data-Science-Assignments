# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Alphabets_data.csv")
df
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 0          T     2     8      3       5      1     8    13      0      6
# 1          I     5    12      3       7      2    10     5      5      4
# 2          D     4    11      6       8      6    10     6      2      6
# 3          N     7    11      6       6      3     5     9      4      6
# 4          G     2     1      3       1      1     8     6      6      6
# ...      ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19995      D     2     2      3       3      2     7     7      7      6
# 19996      C     7    10      8       8      4     4     8      6      9
# 19997      T     6     9      6       7      5     6    11      3      7
# 19998      S     2     3      4       2      1     8     7      2      6
# 19999      A     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# ...

# %%
print("Number of Unique elements in the given Dataset are: ")
for i in df.columns:
  print(f'{i} has {df[i].nunique()} unique elements in the {i} column')
# Out:
# Number of Unique elements in the given Dataset are:
# letter has 26 unique elements in the letter column
# xbox has 16 unique elements in the xbox column
# ybox has 16 unique elements in the ybox column
# width has 16 unique elements in the width column
# height has 16 unique elements in the height column
# onpix has 16 unique elements in the onpix column
# xbar has 16 unique elements in the xbar column
# ybar has 16 unique elements in the ybar column
# x2bar has 16 unique elements in the x2bar column
# y2bar has 16 unique elements in the y2bar column
# xybar has 16 unique elements in the xybar column
# x2ybar has 16 unique elements in the x2ybar column
# xy2bar has 16 unique elements in the xy2bar column
# xedge has 16 unique elements in the xedge column
# xedgey has 16 unique elements in the xedgey column
# yedge has 16 unique elements in the yedge column
# yedgex has 16 unique elements in the yedgex column

# %%
#The given dataset has 2000 rows and 17 columns. The letter column has 24 Unique elements and the rest has 16 unique elements.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   letter  20000 non-null  object
#  1   xbox    20000 non-null  int64
#  2   ybox    20000 non-null  int64
#  3   width   20000 non-null  int64
#  4   height  20000 non-null  int64
#  5   onpix   20000 non-null  int64
#  6   xbar    20000 non-null  int64
#  7   ybar    20000 non-null  int64
#  8   x2bar   20000 non-null  int64
#  9   y2bar   20000 non-null  int64
#  10  xybar   20000 non-null  int64
#  11  x2ybar  20000 non-null  int64
#  12  xy2bar  20000 non-null  int64
#  13  xedge   20000 non-null  int64
#  14  xedgey  20000 non-null  int64
#  15  yedge   20000 non-null  int64
#  16  yedgex  20000 non-null  int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB

# %%
df.dtypes
# Out:
# letter    object
# xbox       int64
# ybox       int64
# width      int64
# height     int64
# onpix      int64
# xbar       int64
# ybar       int64
# x2bar      int64
# y2bar      int64
# xybar      int64
# x2ybar     int64
# xy2bar     int64
# xedge      int64
# xedgey     int64
# yedge      int64
# yedgex     int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# letter    0
# xbox      0
# ybox      0
# width     0
# height    0
# onpix     0
# xbar      0
# ybar      0
# x2bar     0
# y2bar     0
# xybar     0
# x2ybar    0
# xy2bar    0
# xedge     0
# xedgey    0
# yedge     0
# yedgex    0
# dtype: int64

# %%
df.describe()
# Out:
#                xbox          ybox         width       height         onpix  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#                xbar          ybar         x2bar         y2bar         xybar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(1332)

# %%
df_dupli=df[df.duplicated()]
df_dupli
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 627        I     3     7      4       5      2     7     7      0      7
# 724        L     3     6      3       4      1     1     0      6      6
# 730        I     1     9      0       6      0     7     7      4      4
# 910        X     5    11      6       8      2     7     7      5      4
# 943        O     2     3      2       1      1     8     7      6      4
# ...      ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19948      T     4     5      4       4      2     6    11      2      7
# 19950      O     4     5      5       4      3     7     7      8      5
# 19975      E     1     0      1       0      0     5     8      5      7
# 19987      L     3     7      3       5      1     0     1      6      6
# 19998      S     2     3      4       2      1     8     7      2      6
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# ...

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %%
#Label Encoding
df['letter'] = LabelEncoder().fit_transform(df['letter'])
df
# Out:
#        letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 0          19     2     8      3       5      1     8    13      0      6
# 1           8     5    12      3       7      2    10     5      5      4
# 2           3     4    11      6       8      6    10     6      2      6
# 3          13     7    11      6       6      3     5     9      4      6
# 4           6     2     1      3       1      1     8     6      6      6
# ...       ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19994      19     5     8      7       7      7     7     9      4      8
# 19995       3     2     2      3       3      2     7     7      7      6
# 19996       2     7    10      8       8      4     4     8      6      9
# 19997      19     6     9      6       7      5     6    11      3      7
# 19999       0     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# ...

# %%
x=df.drop(columns='letter')
y=df["letter"]

# %%
x = pd.DataFrame(StandardScaler().fit_transform(x))

# %%
x
# Out:
#              0         1         2         3         4         5         6   \
# 0     -1.144417  0.237070 -1.178294 -0.232716 -1.231474  0.531756  2.358246
# 1      0.451855  1.491943 -1.178294  0.685459 -0.768617  1.515924 -1.090370
# 2     -0.080235  1.178224  0.372167  1.144546  1.082808  1.515924 -0.659293
# 3      1.516037  1.178224  0.372167  0.226371 -0.305761 -0.944497  0.633938
# 4     -1.144417 -1.958957 -1.178294 -2.069066 -1.231474  0.531756 -0.659293
# ...         ...       ...       ...       ...       ...       ...       ...
# 18663  0.451855  0.237070  0.888987  0.685459  1.545665  0.039671  0.633938
# 18664 -1.144417 -1.645239 -1.178294 -1.150891 -0.768617  0.039671 -0.228216
# 18665  1.516037  0.864506  1.405808  1.144546  0.157095 -1.436582  0.202861
# 18666  0.983946  0.550788  0.372167  0.685459  0.619952 -0.452413  1.496092
# 18667 -0.080235  0.550788  0.372167  0.226371 -0.768617  1.023840 -1.090370
#
# ...

# %%
x.columns=df.columns[1:]
x
# Out:
#            xbox      ybox     width    height     onpix      xbar      ybar  \
# 0     -1.144417  0.237070 -1.178294 -0.232716 -1.231474  0.531756  2.358246
# 1      0.451855  1.491943 -1.178294  0.685459 -0.768617  1.515924 -1.090370
# 2     -0.080235  1.178224  0.372167  1.144546  1.082808  1.515924 -0.659293
# 3      1.516037  1.178224  0.372167  0.226371 -0.305761 -0.944497  0.633938
# 4     -1.144417 -1.958957 -1.178294 -2.069066 -1.231474  0.531756 -0.659293
# ...         ...       ...       ...       ...       ...       ...       ...
# 18663  0.451855  0.237070  0.888987  0.685459  1.545665  0.039671  0.633938
# 18664 -1.144417 -1.645239 -1.178294 -1.150891 -0.768617  0.039671 -0.228216
# 18665  1.516037  0.864506  1.405808  1.144546  0.157095 -1.436582  0.202861
# 18666  0.983946  0.550788  0.372167  0.685459  0.619952 -0.452413  1.496092
# 18667 -0.080235  0.550788  0.372167  0.226371 -0.768617  1.023840 -1.090370
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=800)

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential( [tf.keras.layers.Dense(16,activation='relu'),
                       Dense(20,activation='relu'),
                       Dense(26,activation='sigmoid')])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history1 = model.fit(X_train, y_train, epochs=50,batch_size=160, validation_split=0.2)
# Out:
# Epoch 1/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0483 - loss: 3.2841 - val_accuracy: 0.1664 - val_loss: 3.0118
# Epoch 2/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1964 - loss: 2.9281 - val_accuracy: 0.3371 - val_loss: 2.5407
# Epoch 3/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3567 - loss: 2.4325 - val_accuracy: 0.4781 - val_loss: 1.9956
# Epoch 4/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4862 - loss: 1.9131 - val_accuracy: 0.5665 - val_loss: 1.6026
# Epoch 5/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5603 - loss: 1.5867 - val_accuracy: 0.6204 - val_loss: 1.3962
# Epoch 6/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6020 - loss: 1.4049 - val_accuracy: 0.6364 - val_loss: 1.2807
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6314 - loss: 1.2781 - val_accuracy: 0.6592 - val_loss: 1.1989
# Epoch 8/50
# ...

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"accuracy of the model is {test_accuracy}")
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8081 - loss: 0.6334
# accuracy of the model is 0.8114622235298157

# %%
model2 = Sequential([tf.keras.layers.Dense(16,activation='relu'),
                       Dense(20,activation='relu'),
                      Dense(15,activation='tanh'),
                       Dense(26,activation='sigmoid')])
model2.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history2 = model2.fit(X_train, y_train, epochs=100,batch_size=160, validation_split=0.2)
# Out:
# Epoch 1/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0472 - loss: 3.2387 - val_accuracy: 0.1905 - val_loss: 3.0176
# Epoch 2/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2124 - loss: 2.9194 - val_accuracy: 0.2966 - val_loss: 2.5850
# Epoch 3/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3086 - loss: 2.4888 - val_accuracy: 0.3592 - val_loss: 2.2163
# Epoch 4/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3774 - loss: 2.1550 - val_accuracy: 0.4650 - val_loss: 1.9342
# Epoch 5/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4811 - loss: 1.9023 - val_accuracy: 0.5454 - val_loss: 1.7213
# Epoch 6/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5407 - loss: 1.7207 - val_accuracy: 0.5922 - val_loss: 1.5539
# Epoch 7/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5833 - loss: 1.5527 - val_accuracy: 0.6264 - val_loss: 1.4277
# Epoch 8/100
# ...

# %%
test_loss2, test_accuracy2 = model2.evaluate(X_test, y_test)
print("accuracy of the model is", test_accuracy2)
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8350 - loss: 0.5605
# accuracy of the model is 0.8377075791358948

# %%
y_test_predict = model2.predict(X_test)
y_test_pred_labels = [np.argmax(i) for i in y_test_predict]
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
df_new = pd.DataFrame()
df_new['y_test'] = y_test
df_new['labels_pred'] = y_test_pred_labels
df_new
# Out:
#        y_test  labels_pred
# 7612        0            0
# 12033       5            5
# 2960        6           10
# 3846       24           24
# 7753       13           13
# ...       ...          ...
# 9860        7            7
# 3710       24           24
# 2455        0            0
# 6999       21           21
# 11047      11           11
#
# [3734 rows x 2 columns]

# %%
#Model1 Vizualisation

# %%
plt.plot(history1.history['accuracy'],label='Train Accuracy')
plt.plot(history1.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model 1 accuracy')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.show()

plt.plot(history1.history['loss'],label='Train Loss')
plt.plot(history1.history['val_loss'], label='Validation Loss')
plt.title('Model 1 Loss over epochs')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
#Model2 Visualization

# %%
plt.plot(history2.history['accuracy'],label='Train Accuracy')
plt.plot(history2.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model 2 accuracy')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.show()

plt.plot(history2.history['loss'],label='Train Loss')
plt.plot(history2.history['val_loss'], label='Validation Loss')
plt.title('Model 2 Loss over epochs')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
#Hyperparameter Tuning

# %%
# !pip install keras_tuner
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 1.9 MB/s eta 0:00:00
# ...

# %%
num_features = X_train.shape[1]
num_classes = len(np.unique(y_train))

# %%
def build_model(hp):
    model = keras.Sequential([
        keras.layers.Dense(
            units=hp.Int('units', min_value=16, max_value=128, step=16),
            activation=hp.Choice('activation', values=['relu', 'tanh', 'sigmoid']),
            input_shape=(num_features,)
        ),
        keras.layers.Dropout(hp.Float('dropout', min_value=0.1, max_value=0.5, step=0.1)),
        keras.layers.Dense(num_classes, activation='softmax')
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=hp.Choice('learning_rate', values=[0.1, 0.01, 0.001, 0.0001])
        ),
        loss='sparse_categorical_crossentropy',  # Use sparse format for integer labels
        metrics=['accuracy']
    )
    return model

# %%
import keras_tuner as kt

# %%
import keras

# %%
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=1,
    directory='keras_tuner_dir',
    project_name='alphabet_ann'
)
tuner.search(X_train, y_train, epochs=10, validation_split=0.2)

best_model = tuner.get_best_models(num_models=1)[0]

test_loss, test_accuracy = best_model.evaluate(X_test, y_test)
print("Best Tuned Test Accuracy:", test_accuracy)
# Out:
# Trial 5 Complete [00h 00m 14s]
# val_accuracy: 0.845329761505127
#
# Best val_accuracy So Far: 0.8975560665130615
# Total elapsed time: 00h 01m 12s
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8796 - loss: 0.3742
# Best Tuned Test Accuracy: 0.8861810564994812

# %%
tuner.search(X_train,y_train,epochs=50,validation_splits=0.2)

# %%
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]
print("best_hyperparameters:",best_hyperparameters.values)
# Out:
# best_hyperparameters: {'units': 128, 'activation': 'sigmoid', 'dropout': 0.30000000000000004, 'learning_rate': 0.01}

# %%
best_model = tuner.hypermodel.build(best_hyperparameters)
best_model.fit(X_train, y_train, epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3741 - loss: 2.1698 - val_accuracy: 0.7195 - val_loss: 0.9855
# Epoch 2/100
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6752 - loss: 1.0798 - val_accuracy: 0.7851 - val_loss: 0.7523
# Epoch 3/100
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7255 - loss: 0.8875 - val_accuracy: 0.8286 - val_loss: 0.6075
# Epoch 4/100
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7637 - loss: 0.7612 - val_accuracy: 0.8440 - val_loss: 0.5349
# Epoch 5/100
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7853 - loss: 0.6654 - val_accuracy: 0.8644 - val_loss: 0.4788
# Epoch 6/100
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8096 - loss: 0.5962 - val_accuracy: 0.8798 - val_loss: 0.4128
# Epoch 7/100
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8205 - loss: 0.5603 - val_accuracy: 0.8822 - val_loss: 0.3912
# Epoch 8/100
# ...

# %%
train_loss, train_accuracy = best_model.evaluate(X_train, y_train)
print(f"Train Accuracy:  {train_accuracy:.2f}")

test_loss, test_accuracy = best_model.evaluate(X_test, y_test)
print(f"Test Accuracy:  {test_accuracy:.2f}")
# Out:
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9801 - loss: 0.0642
# Train Accuracy:  0.97
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9429 - loss: 0.2027
# Test Accuracy:  0.95

# %%
#Evaluation

# %%
from sklearn.metrics import accuracy_score

y_pred=best_model.predict(X_test).argmax(axis=1)
test_accuracy=accuracy_score(y_test,y_pred)
print("Test accuracy",test_accuracy)
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Test accuracy 0.9453668987680771

# %%
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred, average='macro')     #Use 'macro' or 'weighted'
print("Precision:",f"{precision:.2f}")
# Out:
# Precision: 0.95

# %%
from sklearn.metrics import recall_score

recall = recall_score(y_test, y_pred, average='macro')
print("Recall:",f"{recall:.3f}")
# Out:
# Recall: 0.945

# %%
from sklearn.metrics import f1_score

f1 = f1_score(y_test, y_pred, average='weighted')
print("F1-Score:",f"{f1:.4f}")
# Out:
# F1-Score: 0.9453

# %%
### Discuss the performance differences between the model with default hyperparameters and the tuned model, emphasizing the effects of hyperparameter tuning.

#Hyperparameter tuning significantly enhances model performance by adapting it to the specific dataset characteristics.

#While default parameters provide a fast starting point, tuning often yields models that are more accurate, stable, and generalizable.

#While using a model with default hyperparameters the model may overfit or undefit due to no optimized parameters whereas Tuned model has reduced overfitting/underfitting through regularization parameters.
